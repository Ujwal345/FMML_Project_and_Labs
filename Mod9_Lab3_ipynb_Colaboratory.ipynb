# %% [markdown]
# <a href="https://colab.research.google.com/github/Ujwal345/FMML_Project_and_Labs/blob/main/Mod9_Lab3_ipynb_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ujwal Dhomne**

# %% [markdown]
# Module 9: Neural Networks
#
# Lab 2: Using MLP for multiclass classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the iris dataset
iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# Scale data to have mean 0 and variance 1
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data set into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=2)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1],
             linestyle='none',
             marker='o',
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend();

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3],
             linestyle='none',
             marker='o',
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend();

# %% [markdown]
# MLP for multiclass classification

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
import tqdm

# %%
# Defining the model architecture
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
# Instantiating the model, using Adam optimiser, and Cross Entropy Loss, which is quite commonlu used for classification tasks.
model     = Model(X_train.shape[1])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()

# %% [markdown]
# Train the model

# %%
# Train for 100 epochs
EPOCHS  = 100
X_train = torch.from_numpy(X_train).float()
X_test= torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test)
y_train = torch.from_numpy(y_train)


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()

    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 284.31it/s]

# %% [markdown]
# Plot training progress

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");

# %% [markdown]
# Experiment with the neural network architecture
#
# 1)Try changing the number of hidden layers.
#
# 2)Try changing the number of neurons in the hidden layer.
#
# 3)Try using a different activation function.
# Can you observe any changes?

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, activations
from tensorflow.keras.datasets import mnist

# Load and preprocess the data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Base Model
def create_base_model():
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Experiment 1: Change the number of hidden layers
def create_model_exp1(num_hidden_layers):
    model = models.Sequential()
    model.add(layers.Flatten(input_shape=(28, 28)))
    for _ in range(num_hidden_layers):
        model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))
    return model

# Experiment 2: Change the number of neurons in the hidden layer
def create_model_exp2(num_neurons):
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(num_neurons, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Experiment 3: Use a different activation function
def create_model_exp3(activation_func):
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation=activation_func),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Train and evaluate a given model
def train_and_evaluate(model):
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    model.fit(train_images, train_labels, epochs=5, validation_data=(test_images, test_labels))

# Base Model
print("Base Model:")
base_model = create_base_model()
train_and_evaluate(base_model)

# Experiment 1: Change the number of hidden layers
print("\nExperiment 1: Change the number of hidden layers")
for num_hidden_layers in [1, 2, 3]:
    print(f"\nNumber of hidden layers: {num_hidden_layers}")
    model_exp1 = create_model_exp1(num_hidden_layers)
    train_and_evaluate(model_exp1)

# Experiment 2: Change the number of neurons in the hidden layer
print("\nExperiment 2: Change the number of neurons in the hidden layer")
for num_neurons in [64, 128, 256]:
    print(f"\nNumber of neurons in the hidden layer: {num_neurons}")
    model_exp2 = create_model_exp2(num_neurons)
    train_and_evaluate(model_exp2)

# Experiment 3: Use a different activation function
print("\nExperiment 3: Use a different activation function")
activation_functions = ['relu', 'tanh', 'sigmoid']
for activation_func in activation_functions:
    print(f"\nActivation function: {activation_func}")
    model_exp3 = create_model_exp3(activation_func)
    train_and_evaluate(model_exp3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Base Model:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2610 - accuracy: 0.9253 - val_loss: 0.1399 - val_accuracy: 0.9587
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1154 - accuracy: 0.9665 - val_loss: 0.1087 - val_accuracy: 0.9663
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0803 - accuracy: 0.9758 - val_loss: 0.0857 - val_accuracy: 0.9731
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0606 - accuracy: 0.9812 - val_loss: 0.0773 - val_accuracy: 0.9767
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0468 - accuracy: 0.9855 - val_loss: 0.0779 - val_accuracy: 0.9755
#
# Experiment 1: Change the number of hidden layers
#
# Number of hidden layers: 1
# Epoch 1/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2617 - accuracy: 0.9256 - val_loss: 0.1508 - val_accuracy: 0.9543
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1155 - accuracy: 0.9658 - val_loss: 0.1036 - val_accuracy: 0.9693
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0803 - accuracy: 0.9757 - val_loss: 0.0828 - val_accuracy: 0.9747
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0593 - accuracy: 0.9825 - val_loss: 0.0814 - val_accuracy: 0.9759
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0468 - accuracy: 0.9854 - val_loss: 0.0749 - val_accuracy: 0.9788
#
# Number of hidden layers: 2
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2274 - accuracy: 0.9332 - val_loss: 0.1205 - val_accuracy: 0.9620
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0972 - accuracy: 0.9711 - val_loss: 0.0896 - val_accuracy: 0.9735
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0676 - accuracy: 0.9787 - val_loss: 0.0869 - val_accuracy: 0.9718
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0513 - accuracy: 0.9836 - val_loss: 0.0777 - val_accuracy: 0.9764
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0408 - accuracy: 0.9864 - val_loss: 0.0845 - val_accuracy: 0.9755
#
# Number of hidden layers: 3
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2302 - accuracy: 0.9306 - val_loss: 0.1108 - val_accuracy: 0.9641
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0996 - accuracy: 0.9692 - val_loss: 0.1063 - val_accuracy: 0.9677
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0711 - accuracy: 0.9776 - val_loss: 0.0812 - val_accuracy: 0.9763
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0546 - accuracy: 0.9825 - val_loss: 0.0876 - val_accuracy: 0.9744
# Epoch 5/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0452 - accuracy: 0.9857 - val_loss: 0.0917 - val_accuracy: 0.9741
#
# Experiment 2: Change the number of neurons in the hidden layer
#
# Number of neurons in the hidden layer: 64
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3050 - accuracy: 0.9139 - val_loss: 0.1702 - val_accuracy: 0.9506
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1427 - accuracy: 0.9581 - val_loss: 0.1206 - val_accuracy: 0.9643
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1017 - accuracy: 0.9705 - val_loss: 0.1085 - val_accuracy: 0.9686
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0811 - accuracy: 0.9753 - val_loss: 0.1034 - val_accuracy: 0.9699
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0664 - accuracy: 0.9801 - val_loss: 0.0876 - val_accuracy: 0.9728
#
# Number of neurons in the hidden layer: 128
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2566 - accuracy: 0.9275 - val_loss: 0.1302 - val_accuracy: 0.9612
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1111 - accuracy: 0.9672 - val_loss: 0.1062 - val_accuracy: 0.9657
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0763 - accuracy: 0.9768 - val_loss: 0.0812 - val_accuracy: 0.9751
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0569 - accuracy: 0.9826 - val_loss: 0.0777 - val_accuracy: 0.9754
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0441 - accuracy: 0.9862 - val_loss: 0.0973 - val_accuracy: 0.9707
#
# Number of neurons in the hidden layer: 256
# Epoch 1/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2225 - accuracy: 0.9358 - val_loss: 0.1113 - val_accuracy: 0.9656
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0913 - accuracy: 0.9731 - val_loss: 0.0845 - val_accuracy: 0.9743
# Epoch 3/5
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0603 - accuracy: 0.9815 - val_loss: 0.0779 - val_accuracy: 0.9753
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0433 - accuracy: 0.9859 - val_loss: 0.0686 - val_accuracy: 0.9787
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0324 - accuracy: 0.9895 - val_loss: 0.0623 - val_accuracy: 0.9829
#
# Experiment 3: Use a different activation function
#
# Activation function: relu
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2603 - accuracy: 0.9255 - val_loss: 0.1443 - val_accuracy: 0.9578
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1156 - accuracy: 0.9657 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0785 - accuracy: 0.9761 - val_loss: 0.0889 - val_accuracy: 0.9725
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0578 - accuracy: 0.9828 - val_loss: 0.0763 - val_accuracy: 0.9763
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0450 - accuracy: 0.9861 - val_loss: 0.0704 - val_accuracy: 0.9766
#
# Activation function: tanh
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2877 - accuracy: 0.9174 - val_loss: 0.1663 - val_accuracy: 0.9520
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1382 - accuracy: 0.9598 - val_loss: 0.1136 - val_accuracy: 0.9654
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0926 - accuracy: 0.9725 - val_loss: 0.0980 - val_accuracy: 0.9710
# Epoch 4/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0678 - accuracy: 0.9802 - val_loss: 0.0916 - val_accuracy: 0.9726
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0508 - accuracy: 0.9851 - val_loss: 0.0784 - val_accuracy: 0.9744
#
# Activation function: sigmoid
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.3995 - accuracy: 0.8966 - val_loss: 0.2248 - val_accuracy: 0.9332
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1944 - accuracy: 0.9439 - val_loss: 0.1627 - val_accuracy: 0.9513
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1421 - accuracy: 0.9586 - val_loss: 0.1337 - val_accuracy: 0.9601
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1100 - accuracy: 0.9682 - val_loss: 0.1096 - val_accuracy: 0.9684
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0884 - accuracy: 0.9750 - val_loss: 0.0987 - val_accuracy: 0.9698
